# %%
import numpy as np 
import pandas as pd 
record=pd.read_csv("Titanic-Dataset.csv")

# %%
# simulate a "booking date" column for practice
np.random.seed(42)
random_days = np.random.randint(0, 60, size=len(record))
record["BookingDate"] = pd.to_datetime("1912-01-01") + pd.to_timedelta(random_days, unit="D")
print(record[["PassengerId", "BookingDate"]].head())
print(record["BookingDate"].dtype)  # should say datetime64[ns]
# Out:
#    PassengerId BookingDate
# 0            1  1912-02-08
# 1            2  1912-02-21
# 2            3  1912-01-29
# 3            4  1912-01-15
# 4            5  1912-02-12
# datetime64[us]
